# %% [markdown]
# ## Supply

# %% [markdown]
# Supply is defined as liquidity that is trapped at key resistance and support levels. Stop loss orders for buyers/sellers act as trigger points to unlock liquidity for market makers to fill buy orders.

# %%
# the price spikes to find sellers

# %%
# what you almost need is a report from your model that shows price range on the left and total amount of volume on the right. (support / resistance)
## look for where stop loss orders are placed (represent longs near support lines and shorts near resistance lines)
## (above) look for the big green and red candles in a multi-day/week/month charts
# the market will come up or down to these prices if there is a liquidity mismatch either not enough buyers or enough sellers
# when the market comes up or down to these prices, either the stock will breakout/down OR reverse at that level
# look at higher time frames to also find liquidity levels (res/supp)
# If the separation between the creation of the liquidity area and the first retest comes after an excessive number of days/weeks
# (above) (depending n the timeframe you trade), the level may not hold the same weight as it used to as the market context evolves and orders get pulled.
# if you find two or more liquidity levels nearby — clustering of multiple levels of interest — , market participants will tend to place their stop loss orders at the most extreme level
