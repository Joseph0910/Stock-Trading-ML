# %%
# a class function for model ensembling

# bagging meta-estimator
# forests of randomized trees
# adaboost
# gradient tree boosting
# histogram-based gradient boosting
# voting classifier
# voting regressor
# stacked generalization
