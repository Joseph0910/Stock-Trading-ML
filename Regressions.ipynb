# %%
# linear regression
# logistic regression
# ridge regression
# least angle regression
# bayesian regression
# quantile regression
# robustness regression
# kernel ridge regression
# polynomial regression
# isotonic regression
